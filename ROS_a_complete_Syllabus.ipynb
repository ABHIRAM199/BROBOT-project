# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHIRAM199/BROBOT-project/blob/main/ROS_a_complete_Syllabus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ROS [Robot operating System]

# %% [markdown]
# # Introduction to ROS

# %% [markdown]
# ROS (Robot Operating System) is a flexible framework for writing robot software. It provides tools, libraries, and conventions for developing complex robotic applications. ROS isn't an operating system in the traditional sense but a middleware that allows different parts of a robotic system to communicate and work together.

# %% [markdown]
# **Key Features of ROS**
#
# *   **Distributed Computing:** ROS allows various components (called nodes)
#     of a robotic system to run on multiple devices or computers.
# *   **Code Reusability:** It provides a wide array of pre-written packages
#     for common robotic functionalities.
# *   **Communication Interface:** Nodes communicate via topics, services, or
#     actions, enabling modular and scalable design.
# *   **Support for Simulation:** ROS integrates with simulation tools like
#     Gazebo for testing without real hardware.
#
#     [ROS](https://www.ros.org/)
#
#
# ![Screenshot 2024-11-25 at 12.56.44 PM.png](data:image/png;base64,...)

# %% [markdown]
# #  Components of ROS

# %% [markdown]
# ROS comprises several components that together enable robot programming
#
# **Node** : The basic building block of ROS, responsible for specific tasks
#            like sensing, computation, or control.
#
# **Topic** : Asynchronous communication channel for data exchange between
#             nodes.
#
# **Service** : Synchronous request/response communication between nodes.
#
# **Message** : Data structure used in topics, services, and actions.
#
# **Actionlib** : Framework for long-running tasks requiring feedback and
#                 results.
#
# **ROS Master** : Central registry that enables nodes to find each other and
#                  communicate.
#
# **Parameter Server** : Global storage for configuration data, accessible by
#                        all nodes.

# %% [markdown]
# **Nodes**
#
#
#
# *   A node is a single process in ROS
# *   Nodes are responsible for performing specific tasks, such as reading a
#     sensor, controlling a motor, or processing data.
#
# * Example :
# 1.   A node named `camera_driver` might handle input from a camera.
#
# 2.   Another node, `image_processor`, could process that camera feed.
#
# Nodes communicate with each other to achieve complex tasks

# %% [markdown]
# **Topics**
#
#
#
# *   Topics are the communication channels in ROS that enable nodes to
#     exchange messages.
#
# *   Nodes publish data to a topic or subscribe to a topic to receive data.
#
# For example,
#
# A `camera_node` might publish images to a topic named `/camera/image_raw`.
#
# A `vision_node` subscribes to `/camera/image_raw` to process those images.

# %% [markdown]
# **Messages**
#
#
#
# *   Messages are the data structures used to exchange information between
#     nodes via topics
# *   A message might contain data like integers, floating-point numbers,
#     strings, or even complex structures like images or point clouds.
# *   ROS provides many pre-defined message types, such as:
#
#
#
#
# 1.   `std_msgs/String`: For text data.
# 2.   `sensor_msgs/Image`: For camera images.
# 3.   `geometry_msgs/Twist`: For velocities in linear and angular directions.

# %% [markdown]
# **Services**
#
# Services provide a request/response model for communication.
# Unlike topics, which are unidirectional, services are synchronous and involve  a client and a server:
# * A client sends a request to a service.
# * The server processes the request and sends a response back.
# A service named `/spawn` in a simulator like Gazebo might take a request to spawn a new robot and return confirmation.

# %% [markdown]
# **Actionlib (Actions)**
#
#
# Actions are used for long-running tasks that might require feedback
# during execution, like moving a robotic arm.
#
# Actions use three types of messages:
#
#
# 1.   **Goal :** The desired end state.
# 2.   **Feedback :** Progress updates during execution.
# 3.   **Result :** The final outcome.

# %% [markdown]
# **ROS Master**
#
# * The Master is the backbone of the ROS network
# * It runs as a single process and provides name registration and lookup
#   services to other nodes.
#
# When a node starts, it registers itself with the Master, providing:
#
#
# 1.   Its name
# 2.   The topics it publishes or subscribes to.
# 3.   Any services it offers
#
# Once registered, nodes can discover and communicate directly without involving the Master.

# %% [markdown]
# **Parameter Server**
#
# The Parameter Server is a shared, multi-node dictionary that nodes use to store and retrieve data. Parameters are typically used for configuration and initialization
#
#
#
#
#
# *   A global shared dictionary for storing configuration parameters,
#     accessible to all nodes
# *   Parameters are typically used for static or semi-static settings like
#     robot dimensions, sensor calibration values, or operational limits.
# *   Nodes can read from and write to the Parameter Server.
#
#
# Example:
#
#
# 1.   `rosparam set /robot_name "MyRobot"`: Set a parameter.
# 2.   `rosparam get /robot_name`: Get the value of a parameter
# 3.   `rosparam list`: List all parameters

# %% [markdown]
# #Installing and Configuring Your ROS Environment

# %% [markdown]
# This tutorial walks you through installing ROS and setting up the ROS environment on your computer
#
# [ROS1(Noetic) Installation ](https://wiki.ros.org/noetic/Installation/Ubuntu)

# %% [markdown]
# Prerequisite : be familiar with basic Linux commands

# %% [markdown]
# # Create a ROS workspace

# %% [markdown]
# [See the video and implement](https://wiki.ros.org/ROS/Tutorials/InstallingandConfiguringROSEnvironment)

# %% [markdown]
# # Navigating the ROS Filesystem(optional)

# %% [markdown]
# This tutorial introduces ROS filesystem concepts, and covers using the roscd, rosls, and rospack commandline tools.
#
# **Packages**: Packages are the software organization unit of ROS code. Each package can contain libraries, executables, scripts, or other artifacts.
#
# **Manifests (package.xml)**: A manifest is a description of a package. It serves to define dependencies between packages and to capture meta information about the package like version, maintainer, license, etc...
#
# [Navigating ROS file system](https://wiki.ros.org/ROS/Tutorials/NavigatingTheFilesystem)

# %% [markdown]
# # Understanding ROS Nodes and topics

# %% [markdown]
# This tutorial introduces ROS graph concepts and discusses the use of roscore, rosnode, and rosrun commandline tools.
#
# [Ros nodes with turtlesim](https://wiki.ros.org/ROS/Tutorials/UnderstandingNodes)
#
# see the video and simulate the turtle_sim

# %% [markdown]
# ROS topics :  [link](https://wiki.ros.org/ROS/Tutorials/UnderstandingTopics)

# %% [markdown]
# [Ros topics and nodes deep dive](https://youtu.be/rIPmFy_Ax2A)

# %% [markdown]
# [ROS custom Launch file args,params](https://youtu.be/0-zTU4_S6vY)

# %% [markdown]
# # Writing a Simple Publisher and Subscriber (C++)

# %% [markdown]
# This tutorial covers how to write a publisher and subscriber node in C++.
#
# [writing publisher subscriber](https://wiki.ros.org/ROS/Tutorials/WritingPublisherSubscriber%28c%2B%2B%29)
#
# [Video](https://youtu.be/8bUkLNEu5Ns)
#
# [publisher](https://youtu.be/6RSNjo3kMMM?si=5HorMY2bboXk-hfP)
#
# [subscriber](https://youtu.be/vtoJg7LbxJI?si=0s0bM8OgAfro1jI2https://)
#
# ![Screenshot 2024-11-25 at 4.58.38 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Writing a Simple Publisher and Subscriber (Python)

# %% [markdown]
# This tutorial covers how to write a publisher and subscriber node in python.
#
# [code](https://wiki.ros.org/ROS/Tutorials/WritingPublisherSubscriber%28python%29)
#
# [video 1](https://youtu.be/otGWUZqB9XE)
#
# [publisher](https://youtu.be/JprymETaUVQ?si=KXgiPAdfjBogTyAE)
#
# [subscriber](https://youtu.be/zCIwqiO2W1o?si=Gx25HPfkP2rK15KH)

# %% [markdown]
# # How to install Turtlebot in ROS

# %% [markdown]
# [install Tutlebot](https://youtu.be/pDps6eRyPWk?si=CNkdWEk7yQlFszWX)
#
# [Move Turtlebot](https://youtu.be/2WBDRbYmE7A?si=JSl7I-TL-1Za9y2u)
#
# [collision avoidance](https://youtu.be/Y-bFqQQ3lDs?si=yGc768y0Vnw4Q_j0)

# %% [markdown]
# # ROS command line tools - Topic, Node, Hz, Echo, Bw, Pub

# %% [markdown]
# This video explains two command-line tools - rosnode and rostopic. Both these tools can be used to display and debug information published/subscribed for any given ROS communication scenario
#
# [video](https://youtu.be/_K6b8B87XyQ?si=vw-Ysl-c50U7bTgS)

# %% [markdown]
# # ROS Gmapping | SLAM (simultaneous localization and mapping)

# %% [markdown]
# ROS Mapping using ros Gmapping Package ------------
# In this module, we map an environment in ROS. We visualize the map using RVIZ (3d visualization tool for ROS bases application).
# ROS Gmapping package is being used, which uses the occupancy grid-based mapping algorithm. Thus we say its ros mapping, and also ros gmapping.
# Teleop package has been used to move the turtlebot around to map the environment
#
# [SLAM 1](https://youtu.be/MFqn9i68bfM?si=ZdLdQvWA0IW6Zx5t)

# %% [markdown]
# # How to Create and Publish a Custom Message in ROS

# %% [markdown]
#  write a custom message in ROS. We generate a msg directory and create a .msg file which has our custom message variable. We edit the cmakeList.txt and generate a python script which uses this custom message.
#
#  [Custom message](https://youtu.be/baAE0i8Rzvg?si=NmFQqgzO_cxVYYaz)

# %% [markdown]
# # How to localize a robot in ROS

# %% [markdown]
# **Amcl | ROS Localization | SLAM 2**
#
# we look at how to localize a robot in ros Gazebo Environment.
# We look at how to get the amcl launch file, understand to launch the amcl node.
# ROS Amcl is a probabilistic localization system for a robot moving in 2D. It implements the adaptive (or KLD-sampling) Monte Carlo localization approach (as described by Dieter Fox), which uses a particle filter to track the pose of a robot against a known map.
#
# [SLAM 2](https://youtu.be/ZfQ30rfJb08?si=ICxFjLiVvWOvjU36)

# %% [markdown]
# # ROS Path Planning

# %% [markdown]
# we look at how to make a robot, a turtlebot here in an environment plan its path. We do so by using a global planner along with a local planner.
# The global planner does not have an idea of unmapped obstacles whereas the local planner does.
# We have used navfn as our global planner and dwa local planner for our move base node, which is the node responsible to do path planning in ROS.
#
# [ROS Move Base | SLAM 3](https://youtu.be/X5CPLZ5VTHI?si=D6v6eNZGTvVhW769)
#
# [Move Turtlebot to goal](https://youtu.be/oxDRuBgPOAo?si=bG52tdtFA1cuiHUQ)

# %% [markdown]
# # Build a Custom Robot in ROS

# %% [markdown]
# [URDF](https://youtu.be/JFpg7vG8NXE?si=1Wg4nHeMBnt00rz3)
#
# [Part 2](https://youtu.be/im2epwUiFMU?si=wXjSbSMjoO3MapCI)
#
# [Part 3](https://youtu.be/1bBU_6_ufBo?si=RNd8YZi_Z4Eu8FV8)

# %% [markdown]
# # Simulating Your Custom Robotic Arm In ROS Noetic

# %% [markdown]
# [Solid works to ROS](https://www.youtube.com/watch?v=T_UOIHEol0I&list=PLeEzO_sX5H6TNMBiworxO8RpQlcYfl54y)

# %% [markdown]
# # MoveIt Tutorial

# %% [markdown]
# [MoveIt Noetic Tutorial](https://moveit.github.io/moveit_tutorials/)
#
# Go through ROS2 and MoveIt2 if you have time
# [MoveIt 2 and ROS 2 ](https://moveit.picknik.ai/main/doc/tutorials/getting_started/getting_started.html)

# %% [markdown]
# # sample real world projects

# %% [markdown]
# [Exporting Mobile Robot Solidworks Assembly to ROS](https://youtu.be/et6CEGqmudQ?si=8reBTrqtoOcXBJCr)
#
#
# [Moveo](https://github.com/BCN3D/BCN3D-Moveo/tree/master)
#
# [Moveo-ref](https://www.jesseweisberg.com/moveo-with-ros/)
#
# [3D Printed Humanoid Robot and Control It With Smartphone](https://www.instructables.com/Smartphone-Controlled-3D-Printed-Humanoid-Robot-Us/)
#
# [pib robot 3D printing and assemly](https://pib.rocks/print/)
#
#
# [pib community knowledge base](https://pib-rocks.atlassian.net/wiki/spaces/kb/pages/66224144/Setting+up+pibs+software+on+a+Raspberry+Pi)
